// %%
// you can add other imports here as needed
import mll.*;

// %%
var dag = new DAG();
Op out = dag.x().add(dag.x()).add(dag.lit(5)); // f(x)
Op dout = out.backwards(); // f ’(x)
Util.viewDot(dout.dot());
// Out:
// BufferedImage@709092da: type = 2 DirectColorModel: rmask=ff0000 gmask=ff00 bmask=ff amask=ff000000 IntegerInterleavedRaster: width = 306 height = 404 #Bands = 4 xOff = 0 yOff = 0 dataOffset[0] 0

// %%
var dag = new DAG();
var part1 = dag.x().add(dag.x());
var part2 = dag.y().add(dag.y()).add(dag.y());
var out = part1.add(part2).add(dag.lit(5));
Util.viewDot(out.dot());
Op dout = out.backwards();
Util.viewDot(dout.dot());
// Out:
// BufferedImage@6c7bf6fb: type = 2 DirectColorModel: rmask=ff0000 gmask=ff00 bmask=ff amask=ff000000 IntegerInterleavedRaster: width = 462 height = 764 #Bands = 4 xOff = 0 yOff = 0 dataOffset[0] 0
