// %%
// you can add other imports here as needed
import mll.*;

// %%
var dag = new DAG();
var part1 = dag.lit(1).add(dag.x().neg().exp());
var out = dag.lit(1).div(part1);
System.out.println(out.dot());
Util.viewDot(out.dot());
// Out:
// digraph {
// 	rankdir="TB"
// 	ordering="in"
// 	_5[label="/",];
// 	_0[label="1.0",];
// 	_0 -> _5[];
// 	_4[label="+",];
// 	_0 -> _4[];
// 	_3[label="exp",];
// 	_2[label="neg",];
// 	_1[label="x",color="0.000000 .5 .75",style=filled,fillcolor="0.000000 .5 .75"];
// 	_1 -> _2[];
// 	_2 -> _3[];
// 	_3 -> _4[];
// 	_4 -> _5[];
// }
// BufferedImage@684ec511: type = 2 DirectColorModel: rmask=ff0000 gmask=ff00 bmask=ff amask=ff000000 IntegerInterleavedRaster: width = 135 height = 332 #Bands = 4 xOff = 0 yOff = 0 dataOffset[0] 0

// %%
var x = Util.getx(-5, 5, 100);
var y = Util.gety(x, out);
Util.viewPlot(x, y, "2b");
// Out:
// BufferedImage@354c0015: type = 1 DirectColorModel: rmask=ff0000 gmask=ff00 bmask=ff amask=0 IntegerInterleavedRaster: width = 600 height = 400 #Bands = 3 xOff = 0 yOff = 0 dataOffset[0] 0

// %%
dag = new DAG();
part1 = dag.x().add(dag.x());
var part2 = dag.lit(1).add(dag.lit(1));
var out = part1.add(part2);
System.out.println(out.dot());
Util.viewDot(out.dot());
// Out:
// digraph {
// 	rankdir="TB"
// 	ordering="in"
// 	_4[label="+",];
// 	_2[label="*",];
// 	_0[label="x",color="0.000000 .5 .75",style=filled,fillcolor="0.000000 .5 .75"];
// 	_0 -> _2[];
// 	_1[label="2.0",];
// 	_1 -> _2[];
// 	_2 -> _4[];
// 	_1 -> _4[];
// }
// BufferedImage@42d10879: type = 2 DirectColorModel: rmask=ff0000 gmask=ff00 bmask=ff amask=ff000000 IntegerInterleavedRaster: width = 134 height = 188 #Bands = 4 xOff = 0 yOff = 0 dataOffset[0] 0

// %%
dag = new DAG();
part1 = dag.x().add(dag.lit(5));
var part2 = dag.lit(2).add(dag.lit(3));
out = part1.add(part2);
Util.viewDot(out.dot());
// Out:
// BufferedImage@49b990d4: type = 2 DirectColorModel: rmask=ff0000 gmask=ff00 bmask=ff amask=ff000000 IntegerInterleavedRaster: width = 134 height = 188 #Bands = 4 xOff = 0 yOff = 0 dataOffset[0] 0
